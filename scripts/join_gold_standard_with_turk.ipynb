# %% [markdown]
# ### Join Gold Standard Answers with Turk Answers

# %%
import pandas as pd

# %%
# Turk
lagos_turk = pd.read_csv("../data/mturk_new/lagos_mturk_2019_03_19.csv")
bangkok_turk = pd.read_csv("../data/mturk_new/bangkok_mturk_2019_03_11.csv")
jakarta_turk = pd.read_csv("../data/mturk_new/jakarta_mturk_2019_02_22.csv")

turk_all = pd.concat([lagos_turk, bangkok_turk, jakarta_turk])

# KO
lagos_ko = pd.read_csv("../data/ko/ko_lagos.csv")
lagos_ko = lagos_ko.iloc[:,range(0,10)]
lagos_ko['url'] = lagos_ko['url'].astype(int)
lagos_ko.loc[lagos_ko['url'] < 10, 'url2'] =  'lagos/img0_000' + lagos_ko['url'].astype(str) + '.jpg'
lagos_ko.loc[(lagos_ko['url'] < 100) & (lagos_ko['url'] >= 10), 'url2'] =  'lagos/img0_00' + lagos_ko['url'].astype(str) + '.jpg'
lagos_ko.loc[lagos_ko['url'] >= 100, 'url2'] =  'lagos/img0_0' + lagos_ko['url'].astype(str) + '.jpg'

bangkok_ko = pd.read_csv("../data/ko/ko_bangkok.csv")
bangkok_ko = bangkok_ko.iloc[:,range(0,10)]
bangkok_ko.loc[bangkok_ko['url'] < 10, 'url2'] =  'bangkok/img0_000' + bangkok_ko['url'].astype(str) + '.jpg'
bangkok_ko.loc[(bangkok_ko['url'] < 100) & (bangkok_ko['url'] >= 10), 'url2'] =  'bangkok/img0_00' + bangkok_ko['url'].astype(str) + '.jpg'
bangkok_ko.loc[bangkok_ko['url'] >= 100, 'url2'] =  'bangkok/img0_0' + bangkok_ko['url'].astype(str) + '.jpg'

jakarta_ko = pd.read_csv("../data/ko/ko_jakarta.csv")
jakarta_ko = jakarta_ko.iloc[:,range(0,10)]
jakarta_ko.loc[jakarta_ko['url'] < 10, 'url2'] =  'jakarta/img0_000' + jakarta_ko['url'].astype(str) + '.jpg'
jakarta_ko.loc[(jakarta_ko['url'] < 100) & (jakarta_ko['url'] >= 10), 'url2'] =  'jakarta/img0_00' + jakarta_ko['url'].astype(str) + '.jpg'
jakarta_ko.loc[jakarta_ko['url'] >= 100, 'url2'] =  'jakarta/img0_0' + jakarta_ko['url'].astype(str) + '.jpg'

ko_all = pd.concat([lagos_ko, bangkok_ko, jakarta_ko])

# %%
print(list(ko_all))
print(list(turk_all))
# Out:
# ['url', 'sidewalk', 'Litter', 'pothole', 'clear markings', 'not clear markings', 'no markings', 'cracks', 'side of road markings', 'glitches', 'url2']
# ['HITId', 'HITTypeId', 'Title', 'Description', 'Keywords', 'Reward', 'CreationTime', 'MaxAssignments', 'RequesterAnnotation', 'AssignmentDurationInSeconds', 'AutoApprovalDelayInSeconds', 'Expiration', 'NumberOfSimilarHITs', 'LifetimeInSeconds', 'AssignmentId', 'WorkerId', 'AssignmentStatus', 'AcceptTime', 'SubmitTime', 'AutoApprovalTime', 'ApprovalTime', 'RejectionTime', 'RequesterFeedback', 'WorkTimeInSeconds', 'LifetimeApprovalRate', 'Last30DaysApprovalRate', 'Last7DaysApprovalRate', 'Input.id', 'Input.segment_id', 'Input.osm_id', 'Input.osm_name', 'Input.osm_type', 'Input.start_lat', 'Input.start_long', 'Input.end_lat', 'Input.end_long', 'Input.gsv_metadata', 'Input.copyright', 'Input.date', 'Input.location', 'Input.pano_id', 'Input.status', 'Input.url_img0', 'Input.url_img90', 'Input.url_img180', 'Input.url_img270', 'Answer.Do you see any of the following?.A paved sidewalk', 'Answer.Do you see any of the following?.Litter', 'Answer.annotatedResult.boundingBoxes', 'Answer.annotatedResult.inputImageProperties.height', 'Answer.annotatedResult.inputImageProperties.width', 'Answer.radios.clear', 'Answer.radios.no markings', 'Answer.radios.not clear', 'Approve', 'Reject']

# %%
turk_all['Input.url_img0'].head()
# Out:
# 0    lagos/img0_0550.jpg
# 1    lagos/img0_0690.jpg
# 2    lagos/img0_0690.jpg
# 3    lagos/img0_0527.jpg
# 4    lagos/img0_0527.jpg
# Name: Input.url_img0, dtype: object

# %%
ko_all['url2'].head()
# Out:
# 0    lagos/img0_0003.jpg
# 1    lagos/img0_0010.jpg
# 2    lagos/img0_0016.jpg
# 3    lagos/img0_0029.jpg
# 4    lagos/img0_0054.jpg
# Name: url2, dtype: object

# %%
ko_turk = ko_all.merge(turk_all, left_on='url2', right_on='Input.url_img0', how = 'left')

# %%
ko_turk.head()
# Out:
#    url  sidewalk  Litter  pothole  clear markings  not clear markings  \
# 0    3       1.0     1.0      1.0             2.0                 2.0
# 1    3       1.0     1.0      1.0             2.0                 2.0
# 2   10       2.0     2.0      2.0             2.0                 2.0
# 3   10       2.0     2.0      2.0             2.0                 2.0
# 4   16       1.0     2.0      2.0             1.0                 2.0
#
#    no markings  cracks  side of road markings  glitches  ...    \
# 0          1.0     1.0                    1.0       2.0  ...
# 1          1.0     1.0                    1.0       2.0  ...
# 2          1.0     2.0                    1.0       1.0  ...
# 3          1.0     2.0                    1.0       1.0  ...
# 4          2.0     2.0                    1.0       1.0  ...
#
#   Answer.Do you see any of the following?.A paved sidewalk  \
# 0                                              False
# 1                                               True
# 2                                              False
# 3                                               True
# 4                                               True
#
#   Answer.Do you see any of the following?.Litter  \
# 0                                           True
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#                 Answer.annotatedResult.boundingBoxes  \
# 0  [{"height":327,"label":"Crack","left":18,"top"...
# 1  [{"height":320,"label":"Crack","left":17,"top"...
# 2                                                 []
# 3  [{"height":95,"label":"Pothole","left":232,"to...
# 4  [{"height":31,"label":"Crack","left":16,"top":...
#
#   Answer.annotatedResult.inputImageProperties.height  \
# 0                                                640
# 1                                                640
# 2                                                640
# 3                                                640
# 4                                                640
#
#   Answer.annotatedResult.inputImageProperties.width Answer.radios.clear  \
# 0                                               640                True
# 1                                               640               False
# 2                                               640               False
# 3                                               640               False
# 4                                               640                True
#
#   Answer.radios.no markings Answer.radios.not clear  Approve Reject
# 0                     False                   False      NaN    NaN
# 1                      True                   False      NaN    NaN
# 2                      True                   False      NaN    NaN
# 3                      True                   False      NaN    NaN
# 4                     False                   False      NaN    NaN
#
# [5 rows x 67 columns]

# %%
list(ko_turk)
# Out:
# ['url',
#  'sidewalk',
#  'Litter',
#  'pothole',
#  'clear markings',
#  'not clear markings',
#  'no markings',
#  'cracks',
#  'side of road markings',
#  'glitches',
#  'url2',
#  'HITId',
#  'HITTypeId',
#  'Title',
#  'Description',
#  'Keywords',
#  'Reward',
#  'CreationTime',
#  'MaxAssignments',
#  'RequesterAnnotation',
#  'AssignmentDurationInSeconds',
#  'AutoApprovalDelayInSeconds',
#  'Expiration',
#  'NumberOfSimilarHITs',
#  'LifetimeInSeconds',
#  'AssignmentId',
#  'WorkerId',
#  'AssignmentStatus',
#  'AcceptTime',
#  'SubmitTime',
#  'AutoApprovalTime',
#  'ApprovalTime',
#  'RejectionTime',
#  'RequesterFeedback',
#  'WorkTimeInSeconds',
#  'LifetimeApprovalRate',
#  'Last30DaysApprovalRate',
#  'Last7DaysApprovalRate',
#  'Input.id',
#  'Input.segment_id',
#  'Input.osm_id',
#  'Input.osm_name',
#  'Input.osm_type',
#  'Input.start_lat',
#  'Input.start_long',
#  'Input.end_lat',
#  'Input.end_long',
#  'Input.gsv_metadata',
#  'Input.copyright',
#  'Input.date',
#  'Input.location',
#  'Input.pano_id',
#  'Input.status',
#  'Input.url_img0',
#  'Input.url_img90',
#  'Input.url_img180',
#  'Input.url_img270',
#  'Answer.Do you see any of the following?.A paved sidewalk',
#  'Answer.Do you see any of the following?.Litter',
#  'Answer.annotatedResult.boundingBoxes',
#  'Answer.annotatedResult.inputImageProperties.height',
#  'Answer.annotatedResult.inputImageProperties.width',
#  'Answer.radios.clear',
#  'Answer.radios.no markings',
#  'Answer.radios.not clear',
#  'Approve',
#  'Reject']

# %%
ko_turk.columns = [c.lower().replace(' ', '_') for c in ko_turk.columns]
ko_turk.rename(columns={"answer.do_you_see_any_of_the_following?.a_paved_sidewalk": "turk_sidewalk",
                       "answer.do_you_see_any_of_the_following?.litter": "turk_litter",
                       "answer.radios.no_markings": "turk_no_markings",
                       "answer.radios.not_clear": "turk_not_clear"}, inplace = True)

# %%
pd.crosstab(ko_turk.sidewalk, ko_turk.turk_sidewalk, margins=True)
# Out:
# turk_sidewalk  False  True  All
# sidewalk
# 1.0               64   216  280
# 2.0              256    77  333
# All              320   293  613

# %%
pd.crosstab(ko_turk.litter, ko_turk.turk_litter, margins=True)
# Out:
# turk_litter  False  True  All
# litter
# 1.0             64    34   98
# 2.0            461    54  515
# All            525    88  613

# %%
pd.crosstab(ko_turk.no_markings, ko_turk.turk_no_markings, margins=True)
# Out:
# turk_no_markings  False  True  All
# no_markings
# 1.0                  68   242  310
# 2.0                 286    17  303
# All                 354   259  613

# %%
ko_turk.cracks.value_counts()
# Out:
# 2.0    508
# 1.0    105
# Name: cracks, dtype: int64

# %%
ko_turk['answer.annotatedresult.boundingboxes'].value_counts()
# Out:
# []                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           458
# [{"height":32,"label":"Pothole","left":160,"top":394,"width":149}]                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# [{"height":241,"label":"Crack","left":230,"top":399,"width":225}]                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# [{"height":22,"label":"Crack","left":135,"top":392,"width":299}]                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# [{"height":135,"label":"Crack","left":354,"top":504,"width":177},{"height":202,"label":"Crack","left":158,"top":399,"width":192}]                                                                                                                                                                                                                                                                                                                                                                                              1
# [{"height":94,"label":"Pothole","left":59,"top":441,"width":162},{"height":93,"label":"Pothole","left":253,"top":434,"width":255}]                                                                                                                                                                                                                                                                                                                                                                                             1
# [{"height":49,"label":"Pothole","left":257,"top":387,"width":39},{"height":27,"label":"Pothole","left":441,"top":290,"width":37}]                                                                                                                                                                                                                                                                                                                                                                                              1
# [{"height":227,"label":"Crack","left":194,"top":345,"width":207}]                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# [{"height":147,"label":"Crack","left":206,"top":358,"width":322}]                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# [{"height":115,"label":"Pothole","left":169,"top":522,"width":92}]                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# [{"height":67,"label":"Pothole","left":299,"top":534,"width":95}]                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# [{"height":219,"label":"Crack","left":360,"top":371,"width":163}]                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# [{"height":34,"label":"Crack","left":100,"top":465,"width":39}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# [{"height":72,"label":"Crack","left":148,"top":264,"width":453},{"height":33,"label":"Pothole","left":330,"top":356,"width":53}]                                                                                                                                                                                                                                                                                                                                                                                               1
# [{"height":73,"label":"Pothole","left":0,"top":410,"width":80}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# [{"height":78,"label":"Crack","left":247,"top":441,"width":246},{"height":40,"label":"Crack","left":412,"top":404,"width":227},{"height":140,"label":"Crack","left":1,"top":480,"width":116},{"height":38,"label":"Crack","left":114,"top":466,"width":133},{"height":92,"label":"Crack","left":63,"top":387,"width":54},{"height":23,"label":"Pothole","left":297,"top":378,"width":35},{"height":25,"label":"Pothole","left":445,"top":358,"width":42},{"height":27,"label":"Pothole","left":568,"top":338,"width":47}]      1
# [{"height":24,"label":"Pothole","left":423,"top":435,"width":60}]                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# [{"height":41,"label":"Crack","left":373,"top":510,"width":45}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# [{"height":20,"label":"Pothole","left":551,"top":355,"width":56}]                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# [{"height":206,"label":"Crack","left":171,"top":431,"width":94},{"height":196,"label":"Crack","left":350,"top":444,"width":39}]                                                                                                                                                                                                                                                                                                                                                                                                1
# [{"height":127,"label":"Crack","left":306,"top":257,"width":39}]                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# [{"height":270,"label":"Crack","left":349,"top":364,"width":200}]                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# [{"height":193,"label":"Crack","left":6,"top":341,"width":569}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# [{"height":66,"label":"Crack","left":388,"top":377,"width":239}]                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# [{"height":133,"label":"Crack","left":12,"top":449,"width":68}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# [{"height":188,"label":"Crack","left":402,"top":309,"width":207}]                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# [{"height":161,"label":"Crack","left":117,"top":479,"width":52}]                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# [{"height":70,"label":"Pothole","left":118,"top":541,"width":92}]                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# [{"height":38,"label":"Pothole","left":527,"top":483,"width":34}]                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# [{"height":87,"label":"Crack","left":437,"top":348,"width":56},{"height":165,"label":"Crack","left":510,"top":351,"width":129}]                                                                                                                                                                                                                                                                                                                                                                                                1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# [{"height":96,"label":"Crack","left":21,"top":384,"width":61}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1
# [{"height":88,"label":"Crack","left":10,"top":338,"width":121},{"height":46,"label":"Crack","left":248,"top":428,"width":22}]                                                                                                                                                                                                                                                                                                                                                                                                  1
# [{"height":59,"label":"Crack","left":363,"top":432,"width":243}]                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# [{"height":46,"label":"Crack","left":509,"top":428,"width":108}]                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# [{"height":26,"label":"Pothole","left":439,"top":419,"width":58}]                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# [{"height":53,"label":"Crack","left":189,"top":357,"width":90}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# [{"height":106,"label":"Crack","left":253,"top":445,"width":224}]                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# [{"height":128,"label":"Crack","left":451,"top":381,"width":187}]                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# [{"height":295,"label":"Crack","left":511,"top":336,"width":129}]                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# [{"height":209,"label":"Crack","left":0,"top":398,"width":178}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# [{"height":77,"label":"Pothole","left":115,"top":481,"width":75}]                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# [{"height":62,"label":"Crack","left":0,"top":478,"width":139}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1
# [{"height":304,"label":"Crack","left":334,"top":334,"width":62}]                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# [{"height":117,"label":"Crack","left":347,"top":451,"width":121}]                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# [{"height":278,"label":"Crack","left":120,"top":362,"width":165}]                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# [{"height":127,"label":"Pothole","left":0,"top":446,"width":198}]                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# [{"height":326,"label":"Pothole","left":205,"top":301,"width":335},{"height":69,"label":"Crack","left":526,"top":282,"width":114}]                                                                                                                                                                                                                                                                                                                                                                                             1
# [{"height":42,"label":"Crack","left":186,"top":400,"width":103}]                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# [{"height":103,"label":"Pothole","left":365,"top":385,"width":178}]                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# [{"height":156,"label":"Crack","left":253,"top":441,"width":364}]                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# [{"height":22,"label":"Pothole","left":353,"top":360,"width":35}]                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# [{"height":188,"label":"Crack","left":388,"top":315,"width":241},{"height":79,"label":"Crack","left":271,"top":524,"width":96}]                                                                                                                                                                                                                                                                                                                                                                                                1
# [{"height":38,"label":"Crack","left":323,"top":432,"width":31},{"height":38,"label":"Crack","left":192,"top":601,"width":29}]                                                                                                                                                                                                                                                                                                                                                                                                  1
# [{"height":26,"label":"Crack","left":1,"top":499,"width":130},{"height":24,"label":"Crack","left":5,"top":534,"width":115},{"height":22,"label":"Crack","left":133,"top":540,"width":101}]                                                                                                                                                                                                                                                                                                                                     1
# [{"height":286,"label":"Crack","left":84,"top":349,"width":277}]                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# [{"height":123,"label":"Crack","left":192,"top":503,"width":187},{"height":63,"label":"Crack","left":32,"top":405,"width":56},{"height":55,"label":"Pothole","left":238,"top":401,"width":88}]                                                                                                                                                                                                                                                                                                                                 1
# [{"height":46,"label":"Crack","left":214,"top":330,"width":69}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# [{"height":31,"label":"Pothole","left":313,"top":399,"width":43},{"height":23,"label":"Pothole","left":124,"top":364,"width":99}]                                                                                                                                                                                                                                                                                                                                                                                              1
# [{"height":77,"label":"Crack","left":155,"top":439,"width":60}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# [{"height":317,"label":"Crack","left":0,"top":323,"width":637},{"height":60,"label":"Crack","left":83,"top":316,"width":170}]                                                                                                                                                                                                                                                                                                                                                                                                  1
# Name: answer.annotatedresult.boundingboxes, Length: 160, dtype: int64

# %%
list(ko_turk)
# Out:
# ['url',
#  'sidewalk',
#  'litter',
#  'pothole',
#  'clear_markings',
#  'not_clear_markings',
#  'no_markings',
#  'cracks',
#  'side_of_road_markings',
#  'glitches',
#  'url2',
#  'hitid',
#  'hittypeid',
#  'title',
#  'description',
#  'keywords',
#  'reward',
#  'creationtime',
#  'maxassignments',
#  'requesterannotation',
#  'assignmentdurationinseconds',
#  'autoapprovaldelayinseconds',
#  'expiration',
#  'numberofsimilarhits',
#  'lifetimeinseconds',
#  'assignmentid',
#  'workerid',
#  'assignmentstatus',
#  'accepttime',
#  'submittime',
#  'autoapprovaltime',
#  'approvaltime',
#  'rejectiontime',
#  'requesterfeedback',
#  'worktimeinseconds',
#  'lifetimeapprovalrate',
#  'last30daysapprovalrate',
#  'last7daysapprovalrate',
#  'input.id',
#  'input.segment_id',
#  'input.osm_id',
#  'input.osm_name',
#  'input.osm_type',
#  'input.start_lat',
#  'input.start_long',
#  'input.end_lat',
#  'input.end_long',
#  'input.gsv_metadata',
#  'input.copyright',
#  'input.date',
#  'input.location',
#  'input.pano_id',
#  'input.status',
#  'input.url_img0',
#  'input.url_img90',
#  'input.url_img180',
#  'input.url_img270',
#  'turk_sidewalk',
#  'turk_litter',
#  'answer.annotatedresult.boundingboxes',
#  'answer.annotatedresult.inputimageproperties.height',
#  'answer.annotatedresult.inputimageproperties.width',
#  'answer.radios.clear',
#  'turk_no_markings',
#  'turk_not_clear',
#  'approve',
#  'reject']
